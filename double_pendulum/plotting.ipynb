# %%
import numpy as np
from matplotlib import pyplot as plt
un_mse_in = np.load("results/unconstrained_msein.npy")
un_mse_out = np.load("results/unconstrained_mseout.npy")
c_mse_in = np.load("results/vel_T0_exp4_msein.npy")
c_mse_out = np.load("results/vel_T0_exp4_mseout.npy")

# %%
plt.plot(un_mse_in, label="un", )
plt.plot(c_mse_in, label="c")
plt.legend()
plt.show()

# %%
0*torch.randn(3)
# Out:
# tensor([0., -0., 0.])
